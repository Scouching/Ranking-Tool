# %% [markdown]
# # Ranking Tool

# %%
import random

def initialize_rankings(names):
    rankings = {name: 0 for name in names}
    return rankings

def compare_names_in_group(group_names, rankings):
    random.shuffle(group_names)
    for i in range(len(group_names)):
        name1 = group_names[i]
        for j in range(i + 1, len(group_names)):
            name2 = group_names[j]
            choice = input(f"Select name 'A' ({name1}) or 'B' ({name2}): ").upper()
            if choice == 'A':
                rankings[name1] += 1
            elif choice == 'B':
                rankings[name2] += 1

def sort_names(rankings):
    return sorted(rankings, key=lambda name: rankings[name])

if __name__ == "__main__":
    # Prompt user for a list of names
    input_names = input("Enter a list of names separated by commas: ")
    names = [name.strip() for name in input_names.split(',')]

    # Check if the list of names is too short
    if len(names) < 10:
        print("Please enter at least 10 names.")
    else:
        # Create groups from the list of names
        groups = [
            names[0:9], names[10:19], names[20:29], names[30:39], names[40:49],
            names[50:59], names[60:69], names[70:79], names[80:]
        ]

        rankings = initialize_rankings(names)

        for group_num, group_names in enumerate(groups, start=1):
            print(f"Ranking names in Group {group_num} (round 1):")
            compare_names_in_group(group_names, rankings)
            print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ef43c02d7701> in <cell line: 22>()
#      22 if __name__ == "__main__":
#      23     # Prompt user for a list of names
# ---> 24     input_names = input("Enter a list of names separated by commas: ")
#      25     names = [name.strip() for name in input_names.split(',')]
#      26
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Groups

# %%
sorted_names_in_groups = {}

# Invert the rankings within each group
for group_num, group_names in enumerate(groups, start=1):
    inverted_rankings = {name: max(rankings.values()) - rankings[name] for name in group_names}
    sorted_names_in_groups[group_num] = sort_names(inverted_rankings)

# Print sorted names for each group
for group_num, sorted_names in sorted_names_in_groups.items():
    print(f"Sorted names in Group {group_num} (inverted rankings):")
    for i, name in enumerate(sorted_names, start=1):
        print(f"{i}. {name}")
    print()

# Combine the sorted names from all groups into one list
combined_sorted_names = []
for group_num, sorted_names in sorted_names_in_groups.items():
    combined_sorted_names.extend(sorted_names)

# Print the combined sorted list
print("Combined rankings for all groups (inverted rankings):")
for i, name in enumerate(combined_sorted_names, start=1):
    print(f"{name}")
# Out:
# Sorted names in Group 1 (inverted rankings):
# 1. Macklin Celebrini
# 2. Berkly Catton
# 3. Cayden Lindstrom
# 4. Zeev Buium
# 5. Ivan Demidov
# 6. Michael Brandsegg-Nygård
# 7. Luke Misa
# 8. Cole Eiserman
# 9. Adam Jiricek
#
# Sorted names in Group 2 (inverted rankings):
# 1. Nikita Artamonov
# 2. Alfons Freij
# 3. Liam Greentree
# 4. Artyom Levshunov
# 5. Tij Iginla
# 6. Lucas Pettersson
# 7. Andrew Basha
# 8. Sacha Boisvert
# 9. Anton Silayev
#
# Sorted names in Group 3 (inverted rankings):
# 1. Trevor Connelly
# 2. John Mustard
# 3. Emil Hemming
# 4. Topias Hynninen
# 5. Daniil Ustinkov
# 6. Igor Chernyshov
# 7. Marcus Kearsey
# 8. Michael Hage
# 9. Tomas Galvas
#
# Sorted names in Group 4 (inverted rankings):
# 1. Konsta Helenius
# 2. Miguel Marques
# 3. Veeti Väisänen
# 4. Herman Träff
# 5. Noel Fransén
# 6. Carter Yakemchuk
# 7. Dominik Badinka
# 8. Beckett Sennecke
# 9. Ryerson Leenders
#
# Sorted names in Group 5 (inverted rankings):
# 1. Matvei Shuravin
# 2. Carson Wetsch
# 3. Teddy Stiga
# 4. Ryder Ritchie
# 5. Matvei Babenko
# 6. Fyodor Avramov
# 7. Kamil Bednarik
# 8. Adam Jecho
# 9. Aron Kiviharju
#
# Sorted names in Group 6 (inverted rankings):
# 1. Jett Luchanko
# 2. Cole Hutson
# 3. Will Felicio
# 4. Charlie Elick
# 5. Theo Kiss
# 6. Christian Humphreys
# 7. Luke Osburn
# 8. Leon Muggli
# 9. Yegor Klimovich
#
# Sorted names in Group 7 (inverted rankings):
# 1. Karl Sterner
# 2. Ondrej Kos
# 3. Tanner Howe
# 4. Cole Beaudoin
# 5. Christopher Thibodeau
# 6. Raoul Boilard
# 7. Simon Zether
# 8. Petter Vesterheim
# 9. Charles Pardue
#
# Sorted names in Group 8 (inverted rankings):
# 1. Petr Sikora
# 2. Jakub Fibigr
# 3. Jamiro Reber
# 4. Diego Johnson
# 5. Artyom Shchuchinov
# 6. Elias Straume Vatne
# 7. Kevin He
# 8. John Whipple
# 9. Brodie Ziemer
#
# Sorted names in Group 9 (inverted rankings):
# 1. Isac Hedqvist
# 2. Jacob Battaglia
# 3. Kieron Walton
# 4. Brian Lonergan
# 5. Jack Berglund
# 6. Logan Sawyer
# 7. Griffin Erdman
# 8. Maxmilian Curran
# 9. Mikus Vecvanags
#
# Sorted names in Group 10 (inverted rankings):
# 1. Arvid Bergström
# 2. Ilya Pautov
# 3. Hugo Fransson
# 4. Evan Gardner
# 5. Adam Belusko
# 6. Gennadi Chaly
# 7. Kenta Isogai
# 8. Callum Cheynowski
# 9. Roman Luttsev
# 10. Arvid Westlin
# 11. Cedrik Johansson
# 12. Leonid Kolodiy
# 13. Jacob Therrien
# 14. Alexander Rogatko
# 15. Ludvig Johnson
# 16. Vojtech Hambalek
# 17. Martin Neckar
# 18. William Zellers
#
# Combined rankings for all groups (inverted rankings):
# Macklin Celebrini
# Berkly Catton
# Cayden Lindstrom
# Zeev Buium
# Ivan Demidov
# Michael Brandsegg-Nygård
# Luke Misa
# Cole Eiserman
# Adam Jiricek
# Nikita Artamonov
# Alfons Freij
# Liam Greentree
# Artyom Levshunov
# Tij Iginla
# Lucas Pettersson
# Andrew Basha
# Sacha Boisvert
# Anton Silayev
# Trevor Connelly
# John Mustard
# Emil Hemming
# Topias Hynninen
# Daniil Ustinkov
# Igor Chernyshov
# Marcus Kearsey
# Michael Hage
# Tomas Galvas
# Konsta Helenius
# Miguel Marques
# Veeti Väisänen
# Herman Träff
# Noel Fransén
# Carter Yakemchuk
# Dominik Badinka
# Beckett Sennecke
# Ryerson Leenders
# Matvei Shuravin
# Carson Wetsch
# Teddy Stiga
# Ryder Ritchie
# Matvei Babenko
# Fyodor Avramov
# Kamil Bednarik
# Adam Jecho
# Aron Kiviharju
# Jett Luchanko
# Cole Hutson
# Will Felicio
# Charlie Elick
# Theo Kiss
# Christian Humphreys
# Luke Osburn
# Leon Muggli
# Yegor Klimovich
# Karl Sterner
# Ondrej Kos
# Tanner Howe
# Cole Beaudoin
# Christopher Thibodeau
# Raoul Boilard
# Simon Zether
# Petter Vesterheim
# Charles Pardue
# Petr Sikora
# Jakub Fibigr
# Jamiro Reber
# Diego Johnson
# Artyom Shchuchinov
# Elias Straume Vatne
# Kevin He
# John Whipple
# Brodie Ziemer
# Isac Hedqvist
# Jacob Battaglia
# Kieron Walton
# Brian Lonergan
# Jack Berglund
# Logan Sawyer
# Griffin Erdman
# Maxmilian Curran
# Mikus Vecvanags
# Arvid Bergström
# Ilya Pautov
# Hugo Fransson
# Evan Gardner
# Adam Belusko
# Gennadi Chaly
# Kenta Isogai
# Callum Cheynowski
# Roman Luttsev
# Arvid Westlin
# Cedrik Johansson
# Leonid Kolodiy
# Jacob Therrien
# Alexander Rogatko
# Ludvig Johnson
# Vojtech Hambalek
# Martin Neckar
# William Zellers
